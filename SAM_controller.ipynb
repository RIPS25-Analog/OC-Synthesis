# %%
import os
from ultralytics import SAM
import matplotlib.pyplot as plt
import glob
import cv2
import numpy as np
from PIL import Image

# %%
def xywh_to_bbox(x, y, w, h):
    """
    Convert (x, y, w, h) to (x1, y1, x2, y2) format.
    """
    x1 = x
    y1 = y
    x2 = x + w
    y2 = y + h
    return [x1, y1, x2, y2]

def segment_images_from_folder_bbox(folder_path, object_type):
    """
    Segments images in the specified folder using the SAM model with bbox information.
    Assumes folder_path contains two folders: 'images' and 'darknet'.
    Each image in 'images' should have a corresponding label file in 'darknet' with
    bounding box information in the format: x y w h (where x, y are the
    top-left corner coordinates and w, h are the width and height of the bounding box).
    """
    model = SAM("sam2.1_b.pt")
    
    for image_path, bbox_path in zip(sorted(glob.glob(os.path.join(folder_path, 'images', '*.jpg'))), 
                                     sorted(glob.glob(os.path.join(folder_path, 'darknet', '*.txt')))):
        x, y, w, h = 0, 0, 0, 0
        image_dimensions = plt.imread(image_path).shape
        with open(bbox_path, 'r') as f:
            line = f.readline().strip()
            if line:
                x, y, w, h = map(float, line.split()[1:5])  # Skip the class label (first element)
                x, y, w, h = int(x * image_dimensions[1]), int(y * image_dimensions[0]), int(w * image_dimensions[1]), int(h * image_dimensions[0])
                x = x - w // 2
                y = y - h // 2
        os.mkdir(f'data/{object_type}_images_sam2_mask') if not os.path.exists(f'data/{object_type}_images_sam2_mask') else None
        
        # Predict segmentation using the SAM model with bounding box
        results = model(image_path, bboxes=xywh_to_bbox(x, y, w, h))
        for result in results:
            # Display the image with the segmentation mask
            # result.show()

            # Access the masks
            masks = results[0].masks

            # Assuming single class segmentation for simplicity, adjust as needed
            mask = masks[0].data.squeeze().cpu().numpy()  # For multi-class, iterate over masks
            mask = mask.astype(np.uint8) # Convert mask to uint8 if needed)
            mask = cv2.resize(mask, (image_dimensions[1], image_dimensions[0]))
            
            image = cv2.imread(image_path)
            image = cv2.resize(image, (image_dimensions[1], image_dimensions[0]))
            
            # Negate the mask and mask the image
            negative_mask = 1-mask
            print(np.unique(mask))
            negative_image = cv2.bitwise_not(image)
            negative_image = cv2.bitwise_and(negative_image, negative_image, mask=mask)
            masked_image = cv2.bitwise_not(negative_image)

            # negative_mask = negative_mask[y: y + h, x: x + w]  # Crop the mask to the bounding box
            # image = image[y: y + h, x: x + w] # Crop the masked image to the bounding box

            # Save the masked image
            output_dir = f'data/{object_type}_images_sam2_mask'
            if not os.path.exists(output_dir):
                os.makedirs(output_dir, exist_ok=True)
            
            # plt.imshow(negative_mask, cmap='gray')
            # plt.axis('off')
            # plt.show()

            # cv2.imwrite(os.path.join(output_dir, os.path.basename(image_path)), image)
            # cv2.imwrite(os.path.join(output_dir, os.path.basename(image_path).split('.')[0] + '_masked.png'), masked_image)
            cv2.imwrite(os.path.join(output_dir, os.path.basename(image_path).split('.')[0] + '.pbm'), negative_mask*255)
            # img = Image.open(os.path.join(output_dir, os.path.basename(image_path).split('.')[0] + '_mask.jpg'))
            # plt.imshow(img, cmap='gray')
            # plt.axis('off')
            # plt.show()

            # # Plot the masked image
            # plt.imshow(cv2.cvtColor(masked_image, cv2.COLOR_BGR2RGB))
            # plt.axis('off')
            # plt.show()

if __name__ == "__main__":
    folder_path = 'download/croissant'
    segment_images_from_folder_bbox(folder_path, 'croissant')
# Out:
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/007762c8816ddf93.jpg: 1024x1024 1 0, 115.2ms
# Speed: 2.7ms preprocess, 115.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/00b6c796919ea125.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.7ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/00c3a38d7a8c908b.jpg: 1024x1024 1 0, 99.7ms
# Speed: 2.6ms preprocess, 99.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/018d3b8f75ec8e49.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.6ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0289d6d41d805a35.jpg: 1024x1024 1 0, 102.0ms
# Speed: 2.6ms preprocess, 102.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/02bec769127e33fc.jpg: 1024x1024 1 0, 100.1ms
# Speed: 2.6ms preprocess, 100.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/03dc0a5aef2c3a1b.jpg: 1024x1024 1 0, 99.3ms
# Speed: 2.6ms preprocess, 99.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0490477f38e17a08.jpg: 1024x1024 1 0, 101.3ms
# Speed: 2.8ms preprocess, 101.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0545669b2773cece.jpg: 1024x1024 1 0, 99.2ms
# Speed: 2.5ms preprocess, 99.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0708ba0491d34c56.jpg: 1024x1024 1 0, 99.3ms
# Speed: 2.5ms preprocess, 99.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0902c27d391e4898.jpg: 1024x1024 1 0, 99.5ms
# Speed: 2.6ms preprocess, 99.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/093099d8d308c897.jpg: 1024x1024 1 0, 99.2ms
# Speed: 2.5ms preprocess, 99.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0a58e8ef7af3fb00.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.4ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0a66e1b5005b62aa.jpg: 1024x1024 1 0, 99.7ms
# Speed: 2.6ms preprocess, 99.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0a8ff071080cd3fb.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.7ms preprocess, 99.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0adf0da0708cc6b9.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.7ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0d67c091fd819031.jpg: 1024x1024 1 0, 99.7ms
# Speed: 2.4ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0e4bf084d6b8b360.jpg: 1024x1024 1 0, 99.3ms
# Speed: 2.4ms preprocess, 99.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/0f0cd67b0b77c7fa.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.7ms preprocess, 99.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/11be168444d8f93a.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.6ms preprocess, 99.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/15a0f343cc9544a6.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.6ms preprocess, 99.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/1737882464cdde47.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.7ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/179d5ecaf0fd2e9c.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.6ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/183d683162a978d8.jpg: 1024x1024 1 0, 99.7ms
# Speed: 2.6ms preprocess, 99.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/190ab585fd379f0f.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.6ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/1939a13eefa89971.jpg: 1024x1024 1 0, 99.7ms
# Speed: 2.6ms preprocess, 99.7ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/1b4509be5d1d4801.jpg: 1024x1024 1 0, 100.1ms
# Speed: 2.7ms preprocess, 100.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/1b9f0d44d6f66ae9.jpg: 1024x1024 1 0, 99.5ms
# Speed: 2.6ms preprocess, 99.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/1c13e53bf6245f17.jpg: 1024x1024 1 0, 99.6ms
# Speed: 2.4ms preprocess, 99.6ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/1cb282b7b1977666.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.4ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/1ea08737696f8246.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.4ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/1f2b90ab3498a224.jpg: 1024x1024 1 0, 99.5ms
# Speed: 2.7ms preprocess, 99.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/1ff24de9fd5bd776.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.6ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/21ed86dd55ef5257.jpg: 1024x1024 1 0, 99.7ms
# Speed: 2.6ms preprocess, 99.7ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/257eece074654dbb.jpg: 1024x1024 1 0, 99.5ms
# Speed: 2.6ms preprocess, 99.5ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/2646412c48fa2d2f.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.5ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/269cb2df447f4baa.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.6ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/27111a7799d70394.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.7ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/2acf8b0dae5c7af6.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.5ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/2b654d1eb49272c2.jpg: 1024x1024 1 0, 99.7ms
# Speed: 2.7ms preprocess, 99.7ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/2e104bbc653c599c.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.6ms preprocess, 100.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/2fb9ae0cff508a2d.jpg: 1024x1024 1 0, 99.6ms
# Speed: 2.5ms preprocess, 99.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/3154c93886b383a1.jpg: 1024x1024 1 0, 100.6ms
# Speed: 2.5ms preprocess, 100.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/34c265e1d4ac256a.jpg: 1024x1024 1 0, 99.7ms
# Speed: 2.5ms preprocess, 99.7ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/36aacedff7138a55.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.6ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/36b501fc3e20d3d7.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.4ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/36dd21f5006a6b69.jpg: 1024x1024 1 0, 99.6ms
# Speed: 2.6ms preprocess, 99.6ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/3acda794a073243e.jpg: 1024x1024 1 0, 99.5ms
# Speed: 2.6ms preprocess, 99.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/3ad02019ef9f66b7.jpg: 1024x1024 1 0, 98.5ms
# Speed: 2.8ms preprocess, 98.5ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/3c0bb1badc411568.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.7ms preprocess, 99.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/3e1bb5144609f6f0.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.6ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/3e48e4b8fc8ffc50.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.6ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/41d3867513859995.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.5ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/4241963da95c6d25.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.9ms preprocess, 99.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/42fb8ee509c95329.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.6ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/43a8a67edf9acde1.jpg: 1024x1024 1 0, 100.4ms
# Speed: 2.6ms preprocess, 100.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/4ad9bc1799f369b1.jpg: 1024x1024 1 0, 100.8ms
# Speed: 3.9ms preprocess, 100.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/4c78ca8b9906664e.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.7ms preprocess, 100.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/4d86328977b431cc.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.5ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/4f2de134cdf48f66.jpg: 1024x1024 1 0, 100.5ms
# Speed: 2.4ms preprocess, 100.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/4f6f94e222da3982.jpg: 1024x1024 1 0, 100.1ms
# Speed: 2.9ms preprocess, 100.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/504406e151118854.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.6ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/550b83aacb60f436.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.8ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/55c42d40d02922e8.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.6ms preprocess, 100.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/56bc3018aebbbd97.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.4ms preprocess, 99.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/581c0069afaf5513.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.5ms preprocess, 99.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/5abba1adff0c6056.jpg: 1024x1024 1 0, 100.5ms
# Speed: 2.4ms preprocess, 100.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/5c169465bc1096b8.jpg: 1024x1024 1 0, 100.5ms
# Speed: 2.5ms preprocess, 100.5ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/5d617c992b5eca99.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.6ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/5eb2adec5e5add9a.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.7ms preprocess, 100.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/615621a43de6d515.jpg: 1024x1024 1 0, 100.2ms
# Speed: 3.4ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/616aa2e850162402.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.5ms preprocess, 100.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/6443d784cfad8887.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.7ms preprocess, 100.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/67ebaf79be416b7b.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.7ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/6b1fbac158df44db.jpg: 1024x1024 1 0, 99.7ms
# Speed: 2.6ms preprocess, 99.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/6c66bbad3f47dc5d.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.6ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/6f28c325657818b6.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.4ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/70290f53b6d8c1d5.jpg: 1024x1024 1 0, 99.8ms
# Speed: 4.6ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/7144f76f24ab4801.jpg: 1024x1024 1 0, 100.1ms
# Speed: 2.5ms preprocess, 100.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/720aa4e9efa95657.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.4ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/73ef2e92d7bba506.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.4ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/74a760e9b36aee42.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.7ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/78bf56a5cc73c5f7.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.6ms preprocess, 100.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/7df464d7a95aebd4.jpg: 1024x1024 1 0, 100.1ms
# Speed: 2.4ms preprocess, 100.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/85ec9925d7891e25.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.4ms preprocess, 99.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/8626d40f462d8e46.jpg: 1024x1024 1 0, 100.1ms
# Speed: 2.6ms preprocess, 100.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/87d359dcbce4a4ae.jpg: 1024x1024 1 0, 99.9ms
# Speed: 2.4ms preprocess, 99.9ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/88999e30c82b0b27.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.5ms preprocess, 100.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/89523d8e0f695d17.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.5ms preprocess, 100.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/8c0a7a8c607513f5.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.5ms preprocess, 100.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/8c27b83d4496edc6.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.6ms preprocess, 100.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/8cd372586ddb7fa4.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.6ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/8df1a34de379d95b.jpg: 1024x1024 1 0, 100.6ms
# Speed: 2.6ms preprocess, 100.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/906c115ccea8b983.jpg: 1024x1024 1 0, 103.0ms
# Speed: 2.5ms preprocess, 103.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/958c1937ed45892d.jpg: 1024x1024 1 0, 100.0ms
# Speed: 2.6ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/96360179ec2e5243.jpg: 1024x1024 1 0, 100.5ms
# Speed: 2.5ms preprocess, 100.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/970e0cd968a094f8.jpg: 1024x1024 1 0, 100.4ms
# Speed: 2.7ms preprocess, 100.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/9920c75fd705b2e2.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.5ms preprocess, 100.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/9b848e165b2fa179.jpg: 1024x1024 1 0, 100.6ms
# Speed: 2.5ms preprocess, 100.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/9dc1a35c3c017648.jpg: 1024x1024 1 0, 100.8ms
# Speed: 2.5ms preprocess, 100.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/9e944f6d33c90156.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.6ms preprocess, 100.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/9edc242e67fe24af.jpg: 1024x1024 1 0, 100.4ms
# Speed: 2.6ms preprocess, 100.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/a3c0bdffcdbf3260.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.5ms preprocess, 100.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/a9e7de92499790ec.jpg: 1024x1024 1 0, 100.4ms
# Speed: 2.5ms preprocess, 100.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/aa8f6f616304ba5b.jpg: 1024x1024 1 0, 100.8ms
# Speed: 2.5ms preprocess, 100.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/abe4f158f8bab5a9.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.5ms preprocess, 100.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/aedc58116a9e76e8.jpg: 1024x1024 1 0, 100.2ms
# Speed: 2.7ms preprocess, 100.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/afee43a7026f325d.jpg: 1024x1024 1 0, 100.6ms
# Speed: 4.8ms preprocess, 100.6ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b0c99dbc972660ec.jpg: 1024x1024 1 0, 100.1ms
# Speed: 2.5ms preprocess, 100.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b0d42924d2e3a262.jpg: 1024x1024 1 0, 100.1ms
# Speed: 2.7ms preprocess, 100.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b1d672f7cfd31494.jpg: 1024x1024 1 0, 100.7ms
# Speed: 2.7ms preprocess, 100.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b634d1f99c228d70.jpg: 1024x1024 1 0, 101.7ms
# Speed: 2.6ms preprocess, 101.7ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b7a6f701e3bdb921.jpg: 1024x1024 1 0, 101.8ms
# Speed: 2.7ms preprocess, 101.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b8983b46cd407a13.jpg: 1024x1024 1 0, 100.6ms
# Speed: 2.8ms preprocess, 100.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b8ad1268cb404ef7.jpg: 1024x1024 1 0, 101.0ms
# Speed: 2.4ms preprocess, 101.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b945da29d0aa107a.jpg: 1024x1024 1 0, 101.1ms
# Speed: 2.7ms preprocess, 101.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b96ae74f548d63aa.jpg: 1024x1024 1 0, 100.8ms
# Speed: 2.5ms preprocess, 100.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/b9be3aa664d9ed49.jpg: 1024x1024 1 0, 106.2ms
# Speed: 2.6ms preprocess, 106.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/bb96703e8ad95dc6.jpg: 1024x1024 1 0, 100.5ms
# Speed: 2.6ms preprocess, 100.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/c347cd064e074215.jpg: 1024x1024 1 0, 101.1ms
# Speed: 2.6ms preprocess, 101.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/c6083497d453103a.jpg: 1024x1024 1 0, 100.7ms
# Speed: 2.5ms preprocess, 100.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/c662c96ca2706f13.jpg: 1024x1024 1 0, 101.3ms
# Speed: 2.5ms preprocess, 101.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/cba6f7cfa66ea472.jpg: 1024x1024 1 0, 100.7ms
# Speed: 2.5ms preprocess, 100.7ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/cd3f4d5a31007f68.jpg: 1024x1024 1 0, 99.8ms
# Speed: 2.4ms preprocess, 99.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/cf50a809ac12825e.jpg: 1024x1024 1 0, 101.3ms
# Speed: 2.5ms preprocess, 101.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/d3c4ca13096ba176.jpg: 1024x1024 1 0, 100.5ms
# Speed: 2.6ms preprocess, 100.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/d477f9a73099acbd.jpg: 1024x1024 1 0, 100.6ms
# Speed: 2.6ms preprocess, 100.6ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/d7be3d1db78a2dba.jpg: 1024x1024 1 0, 101.2ms
# Speed: 2.4ms preprocess, 101.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/d7cb7fd10eb36cf2.jpg: 1024x1024 1 0, 101.1ms
# Speed: 2.7ms preprocess, 101.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/e21cc6bda694d918.jpg: 1024x1024 1 0, 100.5ms
# Speed: 2.7ms preprocess, 100.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/e24bfeac1f807a34.jpg: 1024x1024 1 0, 101.1ms
# Speed: 2.7ms preprocess, 101.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/e7342aad98c495f5.jpg: 1024x1024 1 0, 100.8ms
# Speed: 2.6ms preprocess, 100.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/e7b25476e757dc09.jpg: 1024x1024 1 0, 100.4ms
# Speed: 2.7ms preprocess, 100.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/e7c2399ac0476366.jpg: 1024x1024 1 0, 100.8ms
# Speed: 2.6ms preprocess, 100.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/e87b868c7df3e0bc.jpg: 1024x1024 1 0, 100.8ms
# Speed: 2.7ms preprocess, 100.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/e97e27695c8cfb5d.jpg: 1024x1024 1 0, 100.7ms
# Speed: 2.6ms preprocess, 100.7ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/ef64ce502d01a0be.jpg: 1024x1024 1 0, 100.3ms
# Speed: 2.6ms preprocess, 100.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/f016bda17301ce9d.jpg: 1024x1024 1 0, 100.8ms
# Speed: 2.5ms preprocess, 100.8ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/f2d030494716aa0c.jpg: 1024x1024 1 0, 100.9ms
# Speed: 2.5ms preprocess, 100.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/faa9363ddd45c2ab.jpg: 1024x1024 1 0, 101.1ms
# Speed: 2.6ms preprocess, 101.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/fe34e2a6d1b58606.jpg: 1024x1024 1 0, 100.8ms
# Speed: 2.4ms preprocess, 100.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]
#
# image 1/1 /home/decla_5ay7wb/RIPS25-AnalogDevices-ObjectDetection/download/croissant/images/ff16ad7f7c794a76.jpg: 1024x1024 1 0, 100.8ms
# Speed: 2.7ms preprocess, 100.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# [0 1]

# %%
for pbm_path in glob.glob('data/croissant_images_sam2_mask/*_mask.jpg'):
    mask = cv2.imread(pbm_path)
    plt.imshow(mask*255, cmap='gray')
    plt.axis('off')
    plt.show()
    # cv2.imwrite(os.path.join('data/cut_and_paste_root/croissant', os.path.basename(pbm_path).split('.')[0]+'.pbm'), mask)

# %%
for imgpath in glob.glob('data/croissant_images_sam2_mask/*.pbm'):
    basenames = [os.path.basename(f) for f in glob.glob('data/cut_and_paste_root/croissant/*')]
    if os.path.basename(imgpath).split('.')[0]+'.jpg' in basenames:
        os.system(f'cp {imgpath} data/cut_and_paste_root/croissant/{os.path.basename(imgpath).split(".")[0]}.pbm')

# %%
os.system('python Cut-and-Paste/dataset_generator.py --scale --rotation --num 5 data/cut_and_paste_root data/cut_and_paste_croissants')
# Out:
# Number of background images : 8124
# List of distractor files collected: []
# Working on data/cut_and_paste_croissants/images/1_none.jpg
# Working on data/cut_and_paste_croissants/images/2_none.jpg
# Working on data/cut_and_paste_croissants/images/3_none.jpg
# Working on data/cut_and_paste_croissants/images/5_none.jpg
# Working on data/cut_and_paste_croissants/images/6_none.jpg
# Working on data/cut_and_paste_croissants/images/4_none.jpg
# Working on data/cut_and_paste_croissants/images/7_none.jpg
# Working on data/cut_and_paste_croissants/images/8_none.jpg
# Working on data/cut_and_paste_croissants/images/9_none.jpg
# Working on data/cut_and_paste_croissants/images/11_none.jpg
# Working on data/cut_and_paste_croissants/images/12_none.jpg
# Working on data/cut_and_paste_croissants/images/13_none.jpg
# Working on data/cut_and_paste_croissants/images/10_none.jpg
# Working on data/cut_and_paste_croissants/images/14_none.jpg
# Working on data/cut_and_paste_croissants/images/15_none.jpg
# Working on data/cut_and_paste_croissants/images/17_none.jpg
# Working on data/cut_and_paste_croissants/images/16_none.jpg
# 0

# %%
# Get image size in bytes
print(cv2.imread('data/cut_and_paste_croissants/images/8_poisson.jpg').shape)
# Out:
# (1920, 2560, 3)
